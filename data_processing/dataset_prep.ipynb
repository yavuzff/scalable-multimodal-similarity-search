# %%
"""
Prepare a subset of the LAION dataset: extract valid images and save corresponding metadata
"""

# %%
import os
import pandas as pd
import subprocess
import glob
import datetime
import shutil

# %%
ENTITY_COUNT = 20000

FULL_LAION_PATH = "/Users/yavuz/data/part-00000-5b54c5d5-bbcf-484d-a2ce-0d6f73df1a36-c000.snappy.parquet"
PREP_DATASET_PATH = f"/Users/yavuz/data/LAION-{ENTITY_COUNT}/"

if os.path.exists(PREP_DATASET_PATH):
    print(f"Warning: {PREP_DATASET_PATH} exists!")
else:
    os.makedirs(PREP_DATASET_PATH)

IMAGES_PATH = PREP_DATASET_PATH + "images"
URLS_PATH = PREP_DATASET_PATH + "urls.txt"
SUCCEEDED_URLS_PATH = PREP_DATASET_PATH + "succeeded-urls.txt"
DATA_PATH = PREP_DATASET_PATH + "metadata.parquet"
# Out:
# Warning: /Users/yavuz/data/LAION-20000/ exists!

# %%
def read_safe_data(path: str, count:int) -> pd.DataFrame:
    """
    Return non-nsfw entries from the full LAION dataset.
    """
    print(f"Reading {count} items from full LAION dataset...")
    df = pd.read_parquet(path)[:count]
    
    nsfw_removed_data = df[df["NSFW"]=="UNLIKELY"]
    print("Size after removing NSFW:", len(nsfw_removed_data))
    
    clean_url_data = nsfw_removed_data[~nsfw_removed_data['URL'].str.contains(',')]
    print("Size after removing URLs with commas:", len(clean_url_data))

    return clean_url_data

# %%
data = read_safe_data(FULL_LAION_PATH, ENTITY_COUNT)
data
# Out:
# Reading 20000 items from full LAION dataset...
# Size after removing NSFW: 18614
# Size after removing URLs with commas: 18162
#           SAMPLE_ID                                                URL  \
# 1      1.060015e+12  https://thumbs.ebaystatic.com/images/g/DYEAAOS...
# 2      3.372497e+12  https://farm1.staticflickr.com/784/40182677504...
# 3      3.820200e+11  https://t2.ftcdn.net/jpg/00/58/35/35/240_F_583...
# 5      2.179119e+12  https://i.pinimg.com/236x/03/38/05/0338055833e...
# 6      1.476880e+11  http://d25hqtnqp5nl24.cloudfront.net/images/pr...
# ...             ...                                                ...
# 19995  1.530866e+12  https://www.digsdigs.com/photos/sweet-shabby-c...
# 19996  1.063230e+11     http://www2.hbdirect.com/coverm/90/2432290.jpg
# 19997  4.247173e+12  https://goalstudio.com/web/product/medium/2020...
# 19998  1.505120e+11  https://thumbs.dreamstime.com/m/clown-toy-colo...
# 19999  3.412030e+12  https://cdn11.bigcommerce.com/s-f90qkbm3hv/ima...
#
#                                                     TEXT  HEIGHT   WIDTH  \
# 1      Silverline Air Framing Nailer 90mm 10 - 12 Gau...   225.0   225.0
# 2                                        Anhui Mountains   800.0   514.0
# 3                             Acute pain in a woman knee   257.0   240.0
# 5             Essentials Barnwood 70-inch TV Media Stand   236.0   236.0
# 6      Actimel vanilla - 8x100g Brand Price Match - C...   140.0   140.0
# ...                                                  ...     ...     ...
# 19995  Http Www Digsdigs Com 33 Sweet Shabby Chic Bed...   480.0   486.0
# 19996                              Rusconi: Revolution *   170.0   170.0
# 19997                      TOTTENHAM 940 BALL CAP - GOLD  1100.0  1460.0
# 19998  Clown toy color vector illustration Royalty Fr...    92.0   130.0
# 19999                       Rivendale 800XL AirBeam tent   500.0   229.0
#
#       LICENSE      NSFW  similarity
# 1           ?  UNLIKELY    0.312485
# 2           ?  UNLIKELY    0.316512
# 3           ?  UNLIKELY    0.344278
# 5           ?  UNLIKELY    0.332799
# 6           ?  UNLIKELY    0.401302
# ...       ...       ...         ...
# 19995       ?  UNLIKELY    0.352294
# 19996       ?  UNLIKELY    0.371127
# 19997       ?  UNLIKELY    0.388634
# 19998       ?  UNLIKELY    0.349995
# 19999       ?  UNLIKELY    0.335180
#
# [18162 rows x 8 columns]

# %%
def write_urls(data: pd.DataFrame, path: str) -> None:
    """
    Writes the URLs found in the dataframe to a file in the given path
    """
    with open(path, "w+") as f:
        for url in data["URL"]:
            f.write(url + "\n")
    print(f"Finished writing {len(data)} URLs to {path}")

write_urls(data, URLS_PATH)
# Out:
# Finished writing 18162 URLs to /Users/yavuz/data/LAION-20000/urls.txt

# %%
def download_images(url_path: str, images_path: str):
    """
    download images from text file with list of urls 
    """
    if os.path.exists(images_path):
        print(f"Warning: {images_path} exists - renaming it...!")
        os.rename(IMAGES_PATH, IMAGES_PATH + datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S"))
        
    subprocess.call(["img2dataset", "--url_list="+url_path, "--output_folder="+images_path, "--thread_count=64", "--image_size=256"])

# %%
download_images(URLS_PATH, IMAGES_PATH)
# Out:
# Starting the downloading of this file
# Sharding file number 1 of 1 called /Users/yavuz/data/LAION-20000/urls.txt
# 2it [02:45, 82.59s/it]
# worker  - success: 0.707 - failed to download: 0.274 - failed to resize: 0.019 - images per sec: 114 - count: 10000
# total   - success: 0.707 - failed to download: 0.274 - failed to resize: 0.019 - images per sec: 114 - count: 10000
# worker  - success: 0.700 - failed to download: 0.281 - failed to resize: 0.019 - images per sec: 108 - count: 8162
# total   - success: 0.704 - failed to download: 0.277 - failed to resize: 0.019 - images per sec: 111 - count: 18162
# File sharded in 2 shards
# Downloading starting now, check your bandwidth speed (with bwm-ng)your cpu (with htop), and your disk usage (with iotop)!

# %%
def get_valid_file_ids(path:str) -> list[int]:
    """
    Return the ids of all files in IMAGES_PATH (recursively) that end with .jpg
    """
    files = glob.glob(path+"/*/*.jpg")
    files = [file.split('/')[-2:] for file in files]
    print(f"Found {len(files)} files")
    
    ids = [int(file[1].split('.')[0]) for file in files]
    ids.sort()
    return ids

# %%
ids = get_valid_file_ids(IMAGES_PATH)
ids
# Out:
# Found 12788 files
# [0,
#  1,
#  2,
#  3,
#  5,
#  6,
#  7,
#  8,
#  9,
#  11,
#  13,
#  14,
#  15,
#  16,
#  17,
#  19,
#  22,
#  24,
#  26,
#  27,
#  28,
#  29,
#  31,
#  33,
#  34,
#  35,
#  38,
#  40,
#  43,
#  44,
#  45,
#  46,
#  47,
#  49,
#  50,
#  51,
#  52,
#  53,
#  54,
#  55,
#  56,
#  57,
#  59,
#  61,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  69,
#  70,
#  71,
#  73,
#  75,
#  76,
#  78,
#  80,
#  83,
#  85,
#  86,
#  88,
#  89,
#  91,
#  93,
#  94,
#  96,
#  97,
#  99,
#  100,
#  101,
#  102,
#  104,
#  105,
#  106,
#  107,
#  109,
#  111,
#  112,
#  113,
#  114,
#  115,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  128,
#  131,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  142,
#  144,
#  147,
#  148,
#  149,
#  150,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  163,
#  164,
#  166,
#  167,
#  169,
#  170,
#  171,
#  172,
#  174,
#  176,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  185,
#  186,
#  190,
#  191,
#  192,
#  193,
#  196,
#  197,
#  199,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  212,
#  213,
#  215,
#  217,
#  218,
#  221,
#  222,
#  223,
#  224,
#  225,
#  229,
#  230,
#  231,
#  233,
#  236,
#  237,
#  238,
#  239,
#  242,
#  243,
#  244,
#  245,
#  247,
#  249,
#  250,
#  252,
#  254,
#  255,
#  256,
#  257,
#  260,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  281,
#  282,
#  284,
#  287,
#  289,
#  291,
#  292,
#  295,
#  296,
#  298,
#  299,
#  300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  321,
#  324,
#  325,
#  327,
#  328,
#  329,
#  331,
#  332,
#  334,
#  336,
#  338,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  350,
#  351,
#  352,
#  353,
#  354,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  370,
#  371,
#  372,
#  373,
#  374,
#  375,
#  376,
#  377,
#  378,
#  380,
#  381,
#  382,
#  383,
#  384,
#  386,
#  389,
#  390,
#  391,
#  393,
#  395,
#  396,
#  399,
#  400,
#  401,
#  402,
#  405,
#  406,
#  408,
#  409,
#  410,
#  413,
#  414,
#  415,
#  416,
#  417,
#  418,
#  419,
#  420,
#  421,
#  422,
#  423,
#  425,
#  426,
#  428,
#  429,
#  430,
#  432,
#  433,
#  434,
#  436,
#  437,
#  438,
#  439,
#  441,
#  442,
#  444,
#  445,
#  447,
#  450,
#  451,
#  452,
#  453,
#  455,
#  458,
#  459,
#  460,
#  461,
#  462,
#  463,
#  465,
#  466,
#  467,
#  468,
#  469,
#  471,
#  473,
#  474,
#  475,
#  477,
#  479,
#  480,
#  481,
#  483,
#  485,
#  487,
#  488,
#  490,
#  493,
#  494,
#  496,
#  497,
#  499,
#  500,
#  501,
#  502,
#  503,
#  505,
#  509,
#  511,
#  514,
#  515,
#  516,
#  518,
#  519,
#  520,
#  521,
#  522,
#  523,
#  524,
#  525,
#  528,
#  529,
#  530,
#  531,
#  532,
#  533,
#  534,
#  536,
#  537,
#  538,
#  540,
#  541,
#  542,
#  543,
#  544,
#  545,
#  546,
#  547,
#  548,
#  551,
#  553,
#  554,
#  555,
#  556,
#  557,
#  561,
#  563,
#  564,
#  567,
#  568,
#  570,
#  572,
#  575,
#  576,
#  577,
#  578,
#  580,
#  582,
#  583,
#  585,
#  586,
#  587,
#  592,
#  596,
#  597,
#  598,
#  599,
#  600,
#  601,
#  602,
#  603,
#  606,
#  607,
#  608,
#  609,
#  610,
#  611,
#  612,
#  613,
#  614,
#  615,
#  616,
#  617,
#  618,
#  619,
#  620,
#  622,
#  623,
#  627,
#  629,
#  630,
#  631,
#  632,
#  634,
#  635,
#  636,
#  637,
#  638,
#  639,
#  640,
#  642,
#  643,
#  644,
#  645,
#  646,
#  647,
#  649,
#  650,
#  651,
#  652,
#  654,
#  656,
#  657,
#  658,
#  659,
#  660,
#  661,
#  662,
#  664,
#  666,
#  667,
#  668,
#  670,
#  671,
#  672,
#  674,
#  676,
#  677,
#  678,
#  679,
#  680,
#  681,
#  682,
#  683,
#  684,
#  686,
#  687,
#  689,
#  690,
#  692,
#  693,
#  698,
#  699,
#  700,
#  701,
#  702,
#  703,
#  704,
#  705,
#  707,
#  708,
#  709,
#  711,
#  712,
#  713,
#  716,
#  717,
#  718,
#  719,
#  720,
#  721,
#  723,
#  726,
#  727,
#  729,
#  731,
#  732,
#  734,
#  735,
#  736,
#  737,
#  738,
#  739,
#  740,
#  742,
#  743,
#  744,
#  746,
#  748,
#  749,
#  750,
#  751,
#  753,
#  754,
#  755,
#  756,
#  757,
#  758,
#  759,
#  760,
#  761,
#  764,
#  765,
#  766,
#  767,
#  773,
#  775,
#  778,
#  779,
#  780,
#  781,
#  782,
#  783,
#  784,
#  785,
#  786,
#  787,
#  790,
#  791,
#  792,
#  793,
#  794,
#  796,
#  797,
#  801,
#  802,
#  804,
#  805,
#  806,
#  807,
#  808,
#  810,
#  811,
#  813,
#  814,
#  815,
#  816,
#  818,
#  819,
#  820,
#  821,
#  822,
#  823,
#  824,
#  825,
#  826,
#  827,
#  828,
#  830,
#  831,
#  832,
#  834,
#  835,
#  837,
#  838,
#  839,
#  840,
#  841,
#  843,
#  845,
#  846,
#  847,
#  849,
#  851,
#  852,
#  853,
#  854,
#  855,
#  857,
#  858,
#  859,
#  860,
#  862,
#  863,
#  865,
#  866,
#  868,
#  870,
#  873,
#  874,
#  875,
#  877,
#  878,
#  882,
#  883,
#  885,
#  886,
#  887,
#  888,
#  889,
#  890,
#  891,
#  892,
#  894,
#  895,
#  896,
#  897,
#  899,
#  900,
#  901,
#  902,
#  905,
#  906,
#  907,
#  908,
#  909,
#  911,
#  915,
#  918,
#  919,
#  921,
#  922,
#  924,
#  925,
#  929,
#  930,
#  931,
#  932,
#  936,
#  937,
#  938,
#  941,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  948,
#  949,
#  950,
#  952,
#  953,
#  954,
#  956,
#  957,
#  958,
#  959,
#  961,
#  962,
#  964,
#  965,
#  966,
#  967,
#  968,
#  970,
#  972,
#  974,
#  976,
#  977,
#  978,
#  979,
#  980,
#  982,
#  983,
#  984,
#  987,
#  988,
#  989,
#  991,
#  992,
#  993,
#  994,
#  995,
#  996,
#  998,
#  999,
#  1001,
#  1002,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  1009,
#  1012,
#  1014,
#  1015,
#  1018,
#  1019,
#  1020,
#  1021,
#  1022,
#  1023,
#  1024,
#  1026,
#  1027,
#  1028,
#  1031,
#  1032,
#  1034,
#  1037,
#  1038,
#  1039,
#  1041,
#  1042,
#  1043,
#  1044,
#  1046,
#  1048,
#  1049,
#  1050,
#  1051,
#  1053,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1065,
#  1067,
#  1068,
#  1069,
#  1070,
#  1071,
#  1072,
#  1073,
#  1074,
#  1075,
#  1076,
#  1077,
#  1078,
#  1079,
#  1082,
#  1083,
#  1084,
#  1086,
#  1087,
#  1089,
#  1091,
#  1092,
#  1093,
#  1094,
#  1095,
#  1096,
#  1097,
#  1099,
#  1102,
#  1103,
#  1104,
#  1105,
#  1108,
#  1110,
#  1111,
#  1112,
#  1114,
#  1116,
#  1117,
#  1119,
#  1120,
#  1122,
#  1123,
#  1124,
#  1125,
#  1126,
#  1127,
#  1128,
#  1130,
#  1133,
#  1135,
#  1136,
#  1138,
#  1140,
#  1141,
#  1142,
#  1143,
#  1144,
#  1145,
#  1146,
#  1147,
#  1148,
#  1149,
#  1150,
#  1151,
#  1152,
#  1153,
#  1154,
#  1155,
#  1156,
#  1157,
#  1159,
#  1160,
#  1163,
#  1164,
#  1165,
#  1166,
#  1167,
#  1168,
#  1169,
#  1170,
#  1171,
#  1172,
#  1173,
#  1174,
#  1177,
#  1178,
#  1179,
#  1180,
#  1181,
#  1182,
#  1184,
#  1185,
#  1186,
#  1188,
#  1189,
#  1190,
#  1192,
#  1193,
#  1194,
#  1195,
#  1197,
#  1198,
#  1200,
#  1204,
#  1206,
#  1207,
#  1208,
#  1209,
#  1210,
#  1211,
#  1212,
#  1213,
#  1214,
#  1215,
#  1216,
#  1217,
#  1219,
#  1221,
#  1223,
#  1224,
#  1225,
#  1226,
#  1228,
#  1229,
#  1230,
#  1231,
#  1232,
#  1234,
#  1235,
#  1236,
#  1237,
#  1239,
#  1241,
#  1242,
#  1243,
#  1245,
#  1248,
#  1249,
#  1250,
#  1252,
#  1253,
#  1255,
#  1256,
#  1257,
#  1259,
#  1260,
#  1261,
#  1262,
#  1263,
#  1264,
#  1267,
#  1268,
#  1269,
#  1270,
#  1271,
#  1272,
#  1273,
#  1274,
#  1275,
#  1276,
#  1277,
#  1278,
#  1280,
#  1281,
#  1282,
#  1283,
#  1284,
#  1285,
#  1286,
#  1287,
#  1289,
#  1290,
#  1291,
#  1292,
#  1293,
#  1294,
#  1295,
#  1296,
#  1297,
#  1299,
#  1300,
#  1302,
#  1303,
#  1306,
#  1308,
#  1309,
#  1310,
#  1311,
#  1312,
#  1313,
#  1314,
#  1316,
#  1317,
#  1318,
#  1319,
#  1320,
#  1321,
#  1324,
#  1325,
#  1327,
#  1328,
#  1329,
#  1330,
#  1331,
#  1332,
#  1335,
#  1337,
#  1339,
#  1340,
#  1341,
#  1343,
#  1344,
#  1345,
#  1346,
#  1347,
#  1352,
#  1353,
#  1355,
#  1356,
#  1357,
#  1358,
#  1360,
#  1361,
#  1362,
#  1364,
#  1365,
#  1366,
#  1369,
#  1370,
#  1372,
#  1373,
#  1374,
#  1375,
#  1376,
#  1382,
#  1384,
#  1385,
#  1386,
#  1388,
#  1389,
#  1390,
#  1391,
#  1392,
#  1394,
#  1395,
#  1396,
#  1397,
#  1399,
#  ...]

# %%
data_with_images = data.iloc[ids]
data_with_images
# Out:
#           SAMPLE_ID                                                URL  \
# 1      1.060015e+12  https://thumbs.ebaystatic.com/images/g/DYEAAOS...
# 2      3.372497e+12  https://farm1.staticflickr.com/784/40182677504...
# 3      3.820200e+11  https://t2.ftcdn.net/jpg/00/58/35/35/240_F_583...
# 5      2.179119e+12  https://i.pinimg.com/236x/03/38/05/0338055833e...
# 7      1.727450e+11  http://cdn.pastemagazine.com/www/articles/2011...
# ...             ...                                                ...
# 19994  4.063788e+12  https://publicauthordotcom.files.wordpress.com...
# 19995  1.530866e+12  https://www.digsdigs.com/photos/sweet-shabby-c...
# 19997  4.247173e+12  https://goalstudio.com/web/product/medium/2020...
# 19998  1.505120e+11  https://thumbs.dreamstime.com/m/clown-toy-colo...
# 19999  3.412030e+12  https://cdn11.bigcommerce.com/s-f90qkbm3hv/ima...
#
#                                                     TEXT  HEIGHT   WIDTH  \
# 1      Silverline Air Framing Nailer 90mm 10 - 12 Gau...   225.0   225.0
# 2                                        Anhui Mountains   800.0   514.0
# 3                             Acute pain in a woman knee   257.0   240.0
# 5             Essentials Barnwood 70-inch TV Media Stand   236.0   236.0
# 7      Ben Affleck Could Be Latest Addition To <em>Th...   320.0   320.0
# ...                                                  ...     ...     ...
# 19994                        Letters over the Wall cover   205.0   300.0
# 19995  Http Www Digsdigs Com 33 Sweet Shabby Chic Bed...   480.0   486.0
# 19997                      TOTTENHAM 940 BALL CAP - GOLD  1100.0  1460.0
# 19998  Clown toy color vector illustration Royalty Fr...    92.0   130.0
# 19999                       Rivendale 800XL AirBeam tent   500.0   229.0
#
#       LICENSE      NSFW  similarity
# 1           ?  UNLIKELY    0.312485
# 2           ?  UNLIKELY    0.316512
# 3           ?  UNLIKELY    0.344278
# 5           ?  UNLIKELY    0.332799
# 7           ?  UNLIKELY    0.353303
# ...       ...       ...         ...
# 19994       ?  UNLIKELY    0.303382
# 19995       ?  UNLIKELY    0.352294
# 19997       ?  UNLIKELY    0.388634
# 19998       ?  UNLIKELY    0.349995
# 19999       ?  UNLIKELY    0.335180
#
# [12788 rows x 8 columns]

# %%
data_with_images = data_with_images.reset_index()
data_with_images
# Out:
#        index     SAMPLE_ID                                                URL  \
# 0          1  1.060015e+12  https://thumbs.ebaystatic.com/images/g/DYEAAOS...
# 1          2  3.372497e+12  https://farm1.staticflickr.com/784/40182677504...
# 2          3  3.820200e+11  https://t2.ftcdn.net/jpg/00/58/35/35/240_F_583...
# 3          5  2.179119e+12  https://i.pinimg.com/236x/03/38/05/0338055833e...
# 4          7  1.727450e+11  http://cdn.pastemagazine.com/www/articles/2011...
# ...      ...           ...                                                ...
# 12783  19994  4.063788e+12  https://publicauthordotcom.files.wordpress.com...
# 12784  19995  1.530866e+12  https://www.digsdigs.com/photos/sweet-shabby-c...
# 12785  19997  4.247173e+12  https://goalstudio.com/web/product/medium/2020...
# 12786  19998  1.505120e+11  https://thumbs.dreamstime.com/m/clown-toy-colo...
# 12787  19999  3.412030e+12  https://cdn11.bigcommerce.com/s-f90qkbm3hv/ima...
#
#                                                     TEXT  HEIGHT   WIDTH  \
# 0      Silverline Air Framing Nailer 90mm 10 - 12 Gau...   225.0   225.0
# 1                                        Anhui Mountains   800.0   514.0
# 2                             Acute pain in a woman knee   257.0   240.0
# 3             Essentials Barnwood 70-inch TV Media Stand   236.0   236.0
# 4      Ben Affleck Could Be Latest Addition To <em>Th...   320.0   320.0
# ...                                                  ...     ...     ...
# 12783                        Letters over the Wall cover   205.0   300.0
# 12784  Http Www Digsdigs Com 33 Sweet Shabby Chic Bed...   480.0   486.0
# 12785                      TOTTENHAM 940 BALL CAP - GOLD  1100.0  1460.0
# 12786  Clown toy color vector illustration Royalty Fr...    92.0   130.0
# 12787                       Rivendale 800XL AirBeam tent   500.0   229.0
#
#       LICENSE      NSFW  similarity
# 0           ?  UNLIKELY    0.312485
# 1           ?  UNLIKELY    0.316512
# 2           ?  UNLIKELY    0.344278
# 3           ?  UNLIKELY    0.332799
# 4           ?  UNLIKELY    0.353303
# ...       ...       ...         ...
# 12783       ?  UNLIKELY    0.303382
# 12784       ?  UNLIKELY    0.352294
# 12785       ?  UNLIKELY    0.388634
# 12786       ?  UNLIKELY    0.349995
# 12787       ?  UNLIKELY    0.335180
#
# [12788 rows x 9 columns]

# %%
write_urls(data_with_images, SUCCEEDED_URLS_PATH)
#download_images(URLS_PATH, IMAGES_PATH)
# Out:
# Finished writing 12788 URLs to /Users/yavuz/data/LAION-20000/succeeded-urls.txt

# %%
# save metadata to parquet
data_with_images.to_parquet(DATA_PATH)

# %%
def move_files(images_path: str):
    """
    Rename (and move files across shards) so that we have a continuous range of file names from 0 to n
    """
    files = glob.glob(IMAGES_PATH+"/*/*.jpg")
    files.sort()

    for i in range(0, len(files)):
        shard = str(i // 10000).zfill(5)
        index = str(i % 10000).zfill(4)
        
        image_file = files[i]
        json_file = image_file.replace(".jpg", ".json")
        
        shutil.move(image_file, f"{images_path}/{shard}/{shard}{index}.jpg")
        shutil.move(json_file, f"{images_path}/{shard}/{shard}{index}.json")

# %%
move_files(IMAGES_PATH)
